# %%
import numpy as np
import pandas as pd
from functools import reduce
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
# compile the list of dataframes you want to merge
df1 = pd.read_table("Data/winemag-data_first150k.csv", sep=',')
df2 = pd.read_table("Data/winemag-data-130k-v2.csv", sep=',')
df3 = pd.read_table("Data/winemag-data-2017-2020.csv", sep=',')

# %%
# compile the list of dataframes you want to merge
data_frames = [df1, df2, df3]

# %%
df_merged = reduce(lambda  left,right: pd.merge(left,right,
                                            how='outer'), data_frames)

# %%
# print df_merged
df_merged.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0         0.0      US  This tremendous 100% varietal wine hails from ...
# 1         1.0   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2         2.0      US  Mac Watson honors the memory of a wine once ma...
# 3         3.0      US  This spent 20 months in 30% new French oak, an...
# 4         4.0  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# ...

# %%
# remove index
df_merged.style.hide_index()
df_merged.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0         0.0      US  This tremendous 100% varietal wine hails from ...
# 1         1.0   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2         2.0      US  Mac Watson honors the memory of a wine once ma...
# 3         3.0      US  This spent 20 months in 30% new French oak, an...
# 4         4.0  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# ...

# %%
df_merged.to_csv("Data/new_WineData.csv", sep=',', na_rep='.', index=False)
df_merged.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'price', 'province', 'region_1', 'region_2', 'variety', 'winery',
#        'taster_name', 'taster_twitter_handle', 'title', 'taster_photo',
#        'vintage'],
#       dtype='object')

# %%
## import data
set_1_path = 'Data/new_WineData.csv'
wine_df = pd.read_csv(set_1_path)
wine_df.head()
# Out:
#   Unnamed: 0 country                                        description  \
# 0        0.0      US  This tremendous 100% varietal wine hails from ...
# 1        1.0   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2        2.0      US  Mac Watson honors the memory of a wine once ma...
# 3        3.0      US  This spent 20 months in 30% new French oak, an...
# 4        4.0  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# ...

# %%
wine_df=wine_df.drop('description', axis=1)
wine_df
# Out:
#        Unnamed: 0    country                           designation  points  \
# 0             0.0         US                     Martha's Vineyard      96
# 1             1.0      Spain  Carodorum Selección Especial Reserva      96
# 2             2.0         US         Special Selected Late Harvest      96
# 3             3.0         US                               Reserve      96
# 4             4.0     France                            La Brûlade      95
# ...           ...        ...                                   ...     ...
# 362010          .   Portugal  Quinta da Fonte Souto Vinho do Souto      94
# 362011          .         US                          Nuts & Bolts      94
# 362012          .      Italy                                     .      94
# 362013          .      Italy                  Madonna delle Querce      94
# 362014          .  Australia                    Tarraford Vineyard      94
#
#         price        province                      region_1  \
# ...

# %%
wine_df.province.unique()
# Out:
# array(['California', 'Northern Spain', 'Oregon', 'Provence',
#        'Northeastern Italy', 'Southwest France', 'Kumeu', 'Washington',
#        'Bulgaria', 'Tuscany', 'France Other', 'Rhône Valley', 'Galicia',
#        'Andalucia', 'Idaho', 'Burgundy', 'Loire Valley', 'New York',
#        'Mendoza Province', 'Victoria', 'Alentejano', 'Piedmont',
#        'Alentejo', 'Champagne', 'Upper Galilee', 'Beira Atlantico',
#        'Veneto', 'Douro', 'Tejo', 'Stellenbosch', 'Levante',
#        'Sicily & Sardinia', 'Southern Italy', 'Languedoc-Roussillon',
#        'Bordeaux', 'Atalanti Valley', 'Catalonia', 'Santorini', 'Florina',
#        'Marchigue', 'Colchagua Valley', 'Curicó Valley', 'Nemea',
#        'Maule Valley', 'Alsace', 'Guerrouane', 'Colinele Dobrogei',
#        'Central Spain', 'Vinho Verde', 'Mosel', 'Rheinhessen',
#        'Golan Heights', 'Württemberg', 'Ahr', 'British Columbia',
#        'Moldova', 'Spain Other', 'Sopron', 'Other', 'Walker Bay', 'Dão',
# ...

# %%
wine_df= pd.get_dummies(wine_df)
wine_df.head()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-12-359c05591d0a> in <module>
# ----> 1 wine_df= pd.get_dummies(wine_df)
#       2 wine_df.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     891         for (col, pre, sep) in zip(data_to_encode.items(), prefix, prefix_sep):
#     892             # col is (column_name, column), use just column data here
# --> 893             dummy = _get_dummies_1d(
#     894                 col[1],
#     895                 prefix=pre,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in _get_dummies_1d(data, prefix, prefix_sep, dummy_na, sparse, drop_first, dtype)
#    1007
#    1008     else:
# -> 1009         dummy_mat = np.eye(number_of_cols, dtype=dtype).take(codes, axis=0)
#    1010
# ...

# %%
wine_df=pd.get_dummies(wine_df.drop(columns=['target']))
wine_df
